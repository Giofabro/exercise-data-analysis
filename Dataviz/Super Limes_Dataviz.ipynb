# %% [markdown]
# # Super Limes

# %%
# !pip install matplotlib
from matplotlib import pyplot as plt

# Import data
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

visits_per_month = [9695, 7909, 10831, 12942, 12495, 16794, 14161, 12762, 12777, 12439, 10309, 8724]

# numbers of limes of different species sold each month
key_limes_per_month = [92.0, 109.0, 124.0, 70.0, 101.0, 79.0, 106.0, 101.0, 103.0, 90.0, 102.0, 106.0]
persian_limes_per_month = [67.0, 51.0, 57.0, 54.0, 83.0, 90.0, 52.0, 63.0, 51.0, 44.0, 64.0, 78.0]
blood_limes_per_month = [75.0, 75.0, 76.0, 71.0, 74.0, 77.0, 69.0, 80.0, 63.0, 69.0, 73.0, 82.0]
# Out:
# Requirement already satisfied: matplotlib in c:\users\arancia-dell\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arancia-dell\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\arancia-dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
x_values = range(len(months))

plt.figure(figsize=(14, 8))

ax1 = plt.subplot(1,2,1)
plt.plot(x_values, visits_per_month, marker='o')
plt.xlabel('months')
plt.ylabel('visitors')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)
plt.title('Page Visits per month')


ax2 = plt.subplot(1,2,2)
plt.plot(x_values, key_limes_per_month, color='blue')
plt.plot(x_values, persian_limes_per_month, color='yellow')
plt.plot(x_values, blood_limes_per_month, color='red')
plt.legend(['Key limes', 'Persian limes', 'Blood limes'])
plt.xlabel('months')
plt.ylabel('limes sold')
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)
plt.title('Limes sales per month')

plt.subplots_adjust(wspace=0.4)

plt.show()

# %%
#plt.savefig('W_Lemos.png')
